# %%
'''
Class 3 Lab

'''
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# read in the CSV file from a URL
drinks = pd.read_csv('https://raw.githubusercontent.com/sinanuozdemir/SF_DAT_15/master/data/drinks.csv', na_filter=False)

# %%
# 1. Show the first 17 rows of drinks
drinks.head(17)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 5   Antigua & Barbuda            102              128             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 11            Bahamas            122              176             51
# 12            Bahrain             42               63              7
# 13         Bangladesh              0                0              0
# 14           Barbados            143              173             36
# 15            Belarus            142              373             42
# 16            Belgium            295               84            212
#
#     total_litres_of_pure_alcohol continent
# 0                            0.0        AS
# 1                            4.9        EU
# 2                            0.7        AF
# 3                           12.4        EU
# 4                            5.9        AF
# 5                            4.9        NA
# 6                            8.3        SA
# 7                            3.8        EU
# 8                           10.4        OC
# 9                            9.7        EU
# 10                           1.3        EU
# 11                           6.3        NA
# 12                           2.0        AS
# 13                           0.0        AS
# 14                           6.3        NA
# 15                          14.4        EU
# 16                          10.5        EU

# %%
# 2. create a variable called beer_servings and use it to store the beer_servings column

beer_servings = drinks.beer_servings
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
# 5      102
# 6      193
# 7       21
# 8      261
# 9      279
# 10      21
# 11     122
# 12      42
# 13       0
# 14     143
# 15     142
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21      76
# 22     173
# 23     245
# 24      31
# 25     231
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    128
# 164     90
# 165    152
# 166    185
# 167      5
# 168      2
# 169     99
# 170    106
# 171      1
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     19
# 178      6
# 179     45
# 180    206
# 181     16
# 182    219
# 183     36
# 184    249
# 185    115
# 186     25
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, dtype: int64

# %%
# 3. Display a dataframe where the only rows are those with continent North America

drinks[drinks.continent == "NA"]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# 84                        Jamaica             82               97
# 109                        Mexico            238               68
# 122                     Nicaragua             78              118
# 130                        Panama            285              104
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 5               45                           4.9        NA
# 11              51                           6.3        NA
# 14              36                           6.3        NA
# 17               8                           6.8        NA
# 32             100                           8.2        NA
# 41              11                           4.4        NA
# 43               5                           4.2        NA
# 50              26                           6.6        NA
# 51               9                           6.2        NA
# 54               2                           2.2        NA
# 68              28                          11.9        NA
# 69               2                           2.2        NA
# 73               1                           5.9        NA
# 74               2                           3.0        NA
# 84               9                           3.4        NA
# 109              5                           5.5        NA
# 122              1                           3.5        NA
# 130             18                           7.2        NA
# 143             32                           7.7        NA
# 144             71                          10.1        NA
# 145             11                           6.3        NA
# 174              7                           6.4        NA
# 184             84                           8.7        NA

# %%
# 4. Create a new dataframe called north_america that holds your answer in 1.
# drinks (the dataframe) should remain unchanged


north_america = drinks[drinks.continent == "NA"]
north_america
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# 84                        Jamaica             82               97
# 109                        Mexico            238               68
# 122                     Nicaragua             78              118
# 130                        Panama            285              104
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 5               45                           4.9        NA
# 11              51                           6.3        NA
# 14              36                           6.3        NA
# 17               8                           6.8        NA
# 32             100                           8.2        NA
# 41              11                           4.4        NA
# 43               5                           4.2        NA
# 50              26                           6.6        NA
# 51               9                           6.2        NA
# 54               2                           2.2        NA
# 68              28                          11.9        NA
# 69               2                           2.2        NA
# 73               1                           5.9        NA
# 74               2                           3.0        NA
# 84               9                           3.4        NA
# 109              5                           5.5        NA
# 122              1                           3.5        NA
# 130             18                           7.2        NA
# 143             32                           7.7        NA
# 144             71                          10.1        NA
# 145             11                           6.3        NA
# 174              7                           6.4        NA
# 184             84                           8.7        NA

# %%
# 5. What is the average wine consumption per person per year in Africa?
print drinks.groupby('continent').wine_servings.mean()

print drinks['wine_servings'][drinks['continent'] == 'AF'].mean()
# Out:
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# NA     24.521739
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64
# 16.2641509434

# %%
# 6. Create a scatter plot between spirit servings and wine servings of all countries
# %matplotlib inline
drinks.plot(x='spirit_servings', y='wine_servings', kind='scatter', alpha=0.3)

# %%
# 7. Show a list of the top 10 spirit drinking countries 
# (show only country names and spirit servings)

drinks[['country', 'spirit_servings']].sort('spirit_servings', ascending=False).head(10)
# Out:
#                 country  spirit_servings
# 68              Grenada              438
# 15              Belarus              373
# 73                Haiti              326
# 141  Russian Federation              326
# 144           St. Lucia              315
# 72               Guyana              302
# 155            Slovakia              293
# 50             Dominica              286
# 169            Thailand              258
# 40         Cook Islands              254

# %%
# 8. Plot 6 histograms of wine servings by continent, 
# remember to share x and share y axis scales!

drinks.wine_servings.hist(by=drinks.continent, sharex=True, sharey=True, figsize=(15,10))
print;

# %%
# 9. What is the average wine consumption in South America?

print drinks['wine_servings'][drinks['continent'] == 'SA'].mean()
# Out:
# 62.4166666667

# %%
# 10. Which continent has the highest on average wine consumption?

test = drinks.groupby('continent').wine_servings.mean()
pandy = pd.DataFrame(test)
pandy.sort('wine_servings', ascending=False).head(1)
# Out:
#            wine_servings
# continent
# EU            142.222222

# %%
#10 take 2
drinks.groupby('continent', as_index=False).wine_servings.mean().sort_index(by='wine_servings', ascending = False).head(1)
# Out:
#   continent  wine_servings
# 2        EU     142.222222
